# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier

# %%
backorder_train = pd.read_csv("D:\data ANALYTICS AND SCIENCE\PROJECT SUBMISSION DATA\manufacturing\product_train.csv")
backorder_train
# Out:
#             sku  national_inv  lead_time  in_transit_qty  forecast_3_month  \
# 0       3921548             8         12               0                 0
# 1       3191009            83          2              33               157
# 2       2935810             8          4               0                 0
# 3       2205847            31          4              63                70
# 4       4953497             3         12               0                 0
# ...         ...           ...        ...             ...               ...
# 250073  3129822            74          8               0                 0
# 250074  3100168             7         12               0                 0
# 250075  3860965             2          8               0                 0
# 250076  3477768            37          8               1                14
# 250077  3279398           154          8               0                 0
#
# ...

# %%
backorder_test = pd.read_csv("D:\data ANALYTICS AND SCIENCE\PROJECT SUBMISSION DATA\manufacturing\product_test.csv")
backorder_test
# Out:
#            sku  national_inv  lead_time  in_transit_qty  forecast_3_month  \
# 0      3799238             2          8               0                 0
# 1      3268515           149          8              42               238
# 2      2857331            11          8               0                 0
# 3      3320909           272          4               0                 0
# 4      3128606            41          8               0                 0
# ...        ...           ...        ...             ...               ...
# 62515  3310849            10         14               0                 0
# 62516  2162382             1          9               0                 0
# 62517  3612796             0          8               0                16
# 62518  2929259             3          8               0                 0
# 62519  2247504            19          8               0                 0
#
#        forecast_6_month  forecast_9_month  sales_1_month  sales_3_month  \
# ...

# %%
#Define the feature columns and target variable
X_train = backorder_train.drop('went_on_backorder', axis=1)
y_train = backorder_train['went_on_backorder']

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

# Define the column transformer
column_transformer = ColumnTransformer(
    transformers=[
        ('encoder', OneHotEncoder(), ['potential_issue', 'deck_risk', 'oe_constraint', 'ppap_risk', 'stop_auto_buy', 'rev_stop'])
    ])

dp_pipe = Pipeline([
    ('preprocessor', column_transformer)
])

# %%
#Fit and transform the training data
train = dp_pipe.fit_transform(X_train)

# %%
#Transform the test data
test = dp_pipe.transform(backorder_test)

# %%
# Step 4: Create the gradient boosting classifier
gbm = GradientBoostingClassifier(random_state=42)

# %%
from sklearn.model_selection import GridSearchCV

# Step 5: Define hyperparameter grid
param_grid = {
    'learning_rate': [0.1, 0.01, 0.001],
    'n_estimators': [50, 100, 200, 500, 700],
    'max_depth': [1, 2, 3, 4, 5, 6, 7],
    'min_samples_leaf': [1, 2, 5, 10]
}

# %%
# Step 6: Create the grid search object
grid_search = GridSearchCV(estimator=gbm, param_grid=param_grid, cv=10)

# Step 7: Fit the grid search to the training data
grid_search.fit(train, y_train)

# Step 8: Get the best parameters
best_params = grid_search.best_params_

# %%
best_params = {
'max_depth': 3,
'n_estimators': 700,
'learning_rate': 0.1,
'min_samples_leaf': 20,
'subsample': 0.9
}

# %%
gbm_model = GradientBoostingClassifier(**best_params)

# %%
#Fit the model on the training data
gbm_model.fit(train, y_train)
# Out:
# GradientBoostingClassifier(min_samples_leaf=20, n_estimators=700, subsample=0.9)

# %%
# Step 4: Fit the gradient boosting classifier
gbm.fit(train, y_train)

# Step 5: Make predictions on the test data
test_score = gbm.predict_proba(test)[:, 1]
test_score
# Out:
# array([0.00659085, 0.00659085, 0.00659085, ..., 0.00659085, 0.00659085,
#        0.00659085])

# %%
import scipy.stats as stats

# Calculate the mode of test_score
mode_score = stats.mode(test_score, keepdims=True)

print(mode_score.mode[0])
# Out:
# 0.006590852508233814

# %%
# Define the threshold
threshold = 0.0066

# Convert probabilities to "Yes" or "No" predictions
yes_no = ['Yes' if score >= threshold else 'No' for score in test_score]

print(yes_no)
# Out:
# ['No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No'
# ...
